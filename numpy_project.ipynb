# %% [markdown]
# <a href="https://colab.research.google.com/github/shanu9540/Demofile/blob/main/numpy_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# Day 1 — NumPy Project
# Student Grade Analyzer
# ==========================================

# Import NumPy
import numpy as np

# ------------------------------------------
# 1. Generate Random Scores
# ------------------------------------------

# Generate 50 random scores between 0 and 100
scores = np.random.randint(0, 100, size=50)

print("Student Scores:\n")
print(scores)

# ------------------------------------------
# 2. Basic Statistics
# ------------------------------------------

mean_score = np.mean(scores)
median_score = np.median(scores)
highest_score = np.max(scores)
lowest_score = np.min(scores)
std_deviation = np.std(scores)

print("\n===== Statistics =====")
print("Mean Score:", mean_score)
print("Median Score:", median_score)
print("Highest Score:", highest_score)
print("Lowest Score:", lowest_score)
print("Standard Deviation:", std_deviation)

# ------------------------------------------
# 3. Percentiles
# ------------------------------------------

p25 = np.percentile(scores, 25)
p50 = np.percentile(scores, 50)
p75 = np.percentile(scores, 75)

print("\n===== Percentiles =====")
print("25th Percentile:", p25)
print("50th Percentile:", p50)
print("75th Percentile:", p75)

# ------------------------------------------
# 4. Boolean Masking
# ------------------------------------------

# Students who failed (< 40)
failed_students = scores[scores < 40]

# Students with distinction (> 85)
distinction_students = scores[scores > 85]

print("\n===== Failed Students (<40) =====")
print(failed_students)

print("\n===== Distinction Students (>85) =====")
print(distinction_students)

# ------------------------------------------
# 5. Normalize Scores (0 to 1)
# Formula:
# (x - min) / (max - min)
# ------------------------------------------

normalized_scores = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))

print("\n===== Normalized Scores =====")
print(normalized_scores)

# ------------------------------------------
# 6. Reshape Array
# 5 Subjects × 10 Students
# ------------------------------------------

reshaped_scores = scores.reshape(5, 10)

print("\n===== Reshaped Scores (5x10) =====")
print(reshaped_scores)

# Row-wise averages
subject_averages = np.mean(reshaped_scores, axis=1)

print("\n===== Subject-wise Average Scores =====")
print(subject_averages)

# ------------------------------------------
# 7. Broadcasting Example
# Add 5 Grace Marks to Everyone
# ------------------------------------------

grace_scores = scores + 5

print("\n===== Scores After Adding Grace Marks =====")
print(grace_scores)

# ------------------------------------------
# BONUS CHALLENGE
# Weighted Final Scores
# Theory = 40%
# Practical = 60%
# ------------------------------------------

# Generate random theory and practical marks
theory_marks = np.random.randint(0, 100, size=50)
practical_marks = np.random.randint(0, 100, size=50)

# Weighted formula
final_scores = (0.4 * theory_marks) + (0.6 * practical_marks)

print("\n===== Theory Marks =====")
print(theory_marks)

print("\n===== Practical Marks =====")
print(practical_marks)

print("\n===== Weighted Final Scores =====")
print(final_scores)

# Final Statistics
print("\n===== Final Weighted Score Statistics =====")
print("Average Final Score:", np.mean(final_scores))
print("Highest Final Score:", np.max(final_scores))
print("Lowest Final Score:", np.min(final_scores))
# Out:
# Student Scores:
#
# [26 70 86 39 72 52 38 53 42 67 62 58 65 99 39 44  2 41 88 37 22 58 20 30
#  30 87 56 98 10 72 91  3 98 80 39 64 94  3 64 81 51 85 71 60 23 82 43 51
#  39 33]
#
# ===== Statistics =====
# Mean Score: 54.36
# Median Score: 54.5
# Highest Score: 99
# Lowest Score: 2
# Standard Deviation: 26.252436077438606
#
# ===== Percentiles =====
# 25th Percentile: 38.25
# 50th Percentile: 54.5
# 75th Percentile: 72.0
#
# ===== Failed Students (<40) =====
# [26 39 38 39  2 37 22 20 30 30 10  3 39  3 23 39 33]
#
# ===== Distinction Students (>85) =====
# [86 99 88 87 98 91 98 94]
#
# ===== Normalized Scores =====
# [0.24742268 0.70103093 0.86597938 0.3814433  0.72164948 0.51546392
#  0.37113402 0.5257732  0.41237113 0.67010309 0.6185567  0.57731959
#  0.64948454 1.         0.3814433  0.43298969 0.         0.40206186
#  0.88659794 0.36082474 0.20618557 0.57731959 0.18556701 0.28865979
#  0.28865979 0.87628866 0.55670103 0.98969072 0.08247423 0.72164948
#  0.91752577 0.01030928 0.98969072 0.80412371 0.3814433  0.63917526
#  0.94845361 0.01030928 0.63917526 0.81443299 0.50515464 0.8556701
#  0.71134021 0.59793814 0.21649485 0.82474227 0.42268041 0.50515464
#  0.3814433  0.31958763]
#
# ===== Reshaped Scores (5x10) =====
# [[26 70 86 39 72 52 38 53 42 67]
#  [62 58 65 99 39 44  2 41 88 37]
#  [22 58 20 30 30 87 56 98 10 72]
#  [91  3 98 80 39 64 94  3 64 81]
#  [51 85 71 60 23 82 43 51 39 33]]
#
# ===== Subject-wise Average Scores =====
# [54.5 53.5 48.3 61.7 53.8]
#
# ===== Scores After Adding Grace Marks =====
# [ 31  75  91  44  77  57  43  58  47  72  67  63  70 104  44  49   7  46
#   93  42  27  63  25  35  35  92  61 103  15  77  96   8 103  85  44  69
#   99   8  69  86  56  90  76  65  28  87  48  56  44  38]
#
# ===== Theory Marks =====
# [ 9 96  1 35 21  6 89  3 73 50 28  4 62 17 16 38 24 83 75  0 91 85 32 28
#  52 69 69 15 34 10 91 76 94  4 29 74  6  3 71 31 92 82 72 73 86 59 29 64
#  86 45]
#
# ===== Practical Marks =====
# [92  6 59 93 96 92 92 71 18 76 76 20 23 89 88 37 52 34 51 16 30 65  8  7
#  40 23 46  7 77 54 45 55 32 69 98 41 26 79 84 66 52 54 56 36 37 45 89 34
#  99 95]
#
# ===== Weighted Final Scores =====
# [58.8 42.  35.8 69.8 66.  57.6 90.8 43.8 40.  65.6 56.8 13.6 38.6 60.2
#  59.2 37.4 40.8 53.6 60.6  9.6 54.4 73.  17.6 15.4 44.8 41.4 55.2 10.2
#  59.8 36.4 63.4 63.4 56.8 43.  70.4 54.2 18.  48.6 78.8 52.  68.  65.2
#  62.4 50.8 56.6 50.6 65.  46.  93.8 75. ]
#
# ===== Final Weighted Score Statistics =====
# Average Final Score: 51.816
# Highest Final Score: 93.8
# Lowest Final Score: 9.6
